# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
with open(r"C:\Users\Thanasis\Downloads\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\Ames_Housing_Feature_Description.txt", 'r') as f:
    print(f.read())
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %%
df = pd.read_csv(r"C:\Users\Thanasis\Downloads\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\Ames_outliers_removed.csv")
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2922  923275080           80        RL          37.0      7937   Pave   NaN
# 2923  923276100           20        RL           NaN      8885   Pave   NaN
# 2924  923400125           85        RL          62.0     10441   Pave   NaN
# 2925  924100070           20        RL          77.0     10010   Pave   NaN
# 2926  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2927 entries, 0 to 2926
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2927 non-null   int64
#  1   MS SubClass      2927 non-null   int64
#  2   MS Zoning        2927 non-null   object
#  3   Lot Frontage     2437 non-null   float64
#  4   Lot Area         2927 non-null   int64
#  5   Street           2927 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2927 non-null   object
#  8   Land Contour     2927 non-null   object
#  9   Utilities        2927 non-null   object
#  10  Lot Config       2927 non-null   object
#  11  Land Slope       2927 non-null   object
#  12  Neighborhood     2927 non-null   object
#  13  Condition 1      2927 non-null   object
#  14  Condition 2      2927 non-null   object
#  15  Bldg Type        2927 non-null   object
# ...

# %%
df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
# ...

# %%
df.drop("PID", axis=1)
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0              20        RL         141.0     31770   Pave   NaN       IR1
# 1              20        RH          80.0     11622   Pave   NaN       Reg
# 2              20        RL          81.0     14267   Pave   NaN       IR1
# 3              20        RL          93.0     11160   Pave   NaN       Reg
# 4              60        RL          74.0     13830   Pave   NaN       IR1
# ...           ...       ...           ...       ...    ...   ...       ...
# 2922           80        RL          37.0      7937   Pave   NaN       IR1
# 2923           20        RL           NaN      8885   Pave   NaN       IR1
# 2924           85        RL          62.0     10441   Pave   NaN       Reg
# 2925           20        RL          77.0     10010   Pave   NaN       Reg
# 2926           60        RL          74.0      9627   Pave   NaN       Reg
#
# ...

# %%
(100 * df.isnull().sum() / len(df)).sort_values()
# Out:
# PID                0.000000
# Sale Condition     0.000000
# Central Air        0.000000
# 1st Flr SF         0.000000
# 2nd Flr SF         0.000000
#                     ...
# Mas Vnr Type      60.642296
# Fence             80.457807
# Alley             93.235395
# Misc Feature      96.412709
# Pool QC           99.590024
# Length: 81, dtype: float64

# %%
def percent_missing(df):
    percent_nan = 100 * df.isnull().sum() / len(df)
    percent_nan = percent_nan[percent_nan > 0].sort_values()
    return percent_nan

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Electrical         0.034165
# Garage Cars        0.034165
# BsmtFin SF 1       0.034165
# Garage Area        0.034165
# BsmtFin SF 2       0.034165
# Bsmt Unf SF        0.034165
# Total Bsmt SF      0.034165
# Bsmt Half Bath     0.068329
# Bsmt Full Bath     0.068329
# Mas Vnr Area       0.785787
# Bsmt Qual          2.733174
# Bsmt Cond          2.733174
# BsmtFin Type 1     2.733174
# BsmtFin Type 2     2.767339
# Bsmt Exposure      2.835668
# Garage Type        5.363854
# Garage Qual        5.432183
# Garage Cond        5.432183
# Garage Yr Blt      5.432183
# Garage Finish      5.432183
# Lot Frontage      16.740690
# Fireplace Qu      48.582166
# Mas Vnr Type      60.642296
# Fence             80.457807
# Alley             93.235395
# Misc Feature      96.412709
# Pool QC           99.590024
# dtype: float64

# %%
sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)

# %%
percent_nan[percent_nan < 1]
# Out:
# Electrical        0.034165
# Garage Cars       0.034165
# BsmtFin SF 1      0.034165
# Garage Area       0.034165
# BsmtFin SF 2      0.034165
# Bsmt Unf SF       0.034165
# Total Bsmt SF     0.034165
# Bsmt Half Bath    0.068329
# Bsmt Full Bath    0.068329
# Mas Vnr Area      0.785787
# dtype: float64

# %%
df[df['Electrical'].isnull()]['Garage Area']
# Out:
# 1576    400.0
# Name: Garage Area, dtype: float64

# %%
df = df.dropna(axis=0, subset=['Electrical', 'Garage Cars'])
#etsi diagrafoume tis grammes tou df opou mia toulaxiston sthlh apo tis Electrical kai Garage Cars einai null

# %%
percent_nan[percent_nan < 1]
# Out:
# Electrical        0.034165
# Garage Cars       0.034165
# BsmtFin SF 1      0.034165
# Garage Area       0.034165
# BsmtFin SF 2      0.034165
# Bsmt Unf SF       0.034165
# Total Bsmt SF     0.034165
# Bsmt Half Bath    0.068329
# Bsmt Full Bath    0.068329
# Mas Vnr Area      0.785787
# dtype: float64

# %%
df[df['Bsmt Full Bath'].isnull()]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1341  903230120           20        RM          99.0      5940   Pave   NaN
# 1497  908154080           20        RL         123.0     47007   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# 1341       IR1          Lvl    AllPub  ...         0     NaN  MnPrv
# 1497       IR1          Lvl    AllPub  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4    2008      ConLD         Abnorml
# 1497          NaN        0       7    2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 81 columns]

# %%
#BSMT (basement) NUMERIC COLUMNS --> fillna 0
bsmt_num_cols = ['BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Total Bsmt SF']
df[bsmt_num_cols] = df[bsmt_num_cols].fillna(0)

#BSMT STRING COLUMNS
bsmt_str_cols = ['Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2']
df[bsmt_str_cols] = df[bsmt_str_cols].fillna('None')
# Out:
# C:\Users\Thanasis\AppData\Local\Temp\ipykernel_4644\2740403664.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[bsmt_num_cols] = df[bsmt_num_cols].fillna(0)
# C:\Users\Thanasis\AppData\Local\Temp\ipykernel_4644\2740403664.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[bsmt_str_cols] = df[bsmt_str_cols].fillna('None')

# %%
percent_nan = percent_missing(df)

# %%
sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)

# %%
df['Mas Vnr Type'] = df['Mas Vnr Type'].fillna('None')
df['Mas Vnr Area'] = df['Mas Vnr Area'].fillna(0)

#recalculate
percent_nan = percent_missing(df)

sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
ax.set_ylim([0, 1])
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)
# Out:
# C:\Users\Thanasis\AppData\Local\Temp\ipykernel_4644\182226760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mas Vnr Type'] = df['Mas Vnr Type'].fillna('None')
# C:\Users\Thanasis\AppData\Local\Temp\ipykernel_4644\182226760.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mas Vnr Area'] = df['Mas Vnr Area'].fillna(0)

# %%
sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)

# %%
gar_str_col = ['Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond']
df[gar_str_col] = df[gar_str_col].fillna('None')

# %%
percent_nan = percent_missing(df)

# %%
sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)

# %%
df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(0)

# %%
df.drop(['Pool QC', 'Misc Feature', 'Alley', 'Fence'], axis=1, inplace=True)

# %%
percent_nan = percent_missing(df)

sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)

# %%
df['Fireplace Qu'].value_counts()
# Out:
# Fireplace Qu
# Gd    741
# TA    600
# Fa     75
# Po     46
# Ex     43
# Name: count, dtype: int64

# %%
df['Fireplace Qu'] = df['Fireplace Qu'].fillna('None')

# %%
df['Lot Frontage']
# Out:
# 0       141.0
# 1        80.0
# 2        81.0
# 3        93.0
# 4        74.0
#         ...
# 2922     37.0
# 2923      NaN
# 2924     62.0
# 2925     77.0
# 2926     74.0
# Name: Lot Frontage, Length: 2925, dtype: float64

# %%
df['Neighborhood']
# Out:
# 0         NAmes
# 1         NAmes
# 2         NAmes
# 3         NAmes
# 4       Gilbert
#          ...
# 2922    Mitchel
# 2923    Mitchel
# 2924    Mitchel
# 2925    Mitchel
# 2926    Mitchel
# Name: Neighborhood, Length: 2925, dtype: object

# %%
sns.boxplot(x=df['Neighborhood'], y=df['Lot Frontage'])
plt.xticks(rotation=90);
plt.figure(figsize=(8,12), dpi=200)

# %%
sns.boxplot(x='Lot Frontage', y='Neighborhood', data=df, orient='h')
plt.figure(figsize=(20,26), dpi=200)

# %%
 #stis grammes me null Lot Frontage, tha valoyme timh to meso oro twn grammwn me idio neighborhood

gb = df.groupby('Neighborhood')['Lot Frontage'].mean()
gb
# Out:
# Neighborhood
# Blmngtn    46.900000
# Blueste    27.300000
# BrDale     21.500000
# BrkSide    55.789474
# ClearCr    88.150000
# CollgCr    71.336364
# Crawfor    69.951807
# Edwards    64.794286
# Gilbert    74.207207
# Greens     41.000000
# GrnHill          NaN
# IDOTRR     62.383721
# Landmrk          NaN
# MeadowV    25.606061
# Mitchel    75.144444
# NAmes      75.210667
# NPkVill    28.142857
# NWAmes     81.517647
# NoRidge    91.629630
# NridgHt    84.184049
# OldTown    61.777293
# SWISU      59.068182
# Sawyer     74.551020
# SawyerW    70.669811
# Somerst    64.549383
# StoneBr    62.173913
# Timber     81.303571
# Veenker    72.000000
# Name: Lot Frontage, dtype: float64

# %%
# aplos kai pio straightforward tropos na to kanoume
# lis = df['Lot Frontage'].isnull()
# for row in lis:
#     if row:
#         row['Lot Frontage'] = gb[row['Neighborhood']]

# %%
#allos tropos, oneliner
df.groupby('Neighborhood')['Lot Frontage'].transform(lambda value: value.fillna(value.mean()))
# Out:
# 0       141.000000
# 1        80.000000
# 2        81.000000
# 3        93.000000
# 4        74.000000
#            ...
# 2922     37.000000
# 2923     75.144444
# 2924     62.000000
# 2925     77.000000
# 2926     74.000000
# Name: Lot Frontage, Length: 2925, dtype: float64

# %%
df['Lot Frontage'] = df.groupby('Neighborhood')['Lot Frontage'].transform(lambda value: value.fillna(value.mean()))

# %%
df.isnull().sum()
# Out:
# PID               0
# MS SubClass       0
# MS Zoning         0
# Lot Frontage      3
# Lot Area          0
#                  ..
# Mo Sold           0
# Yr Sold           0
# Sale Type         0
# Sale Condition    0
# SalePrice         0
# Length: 77, dtype: int64

# %%
df['Lot Frontage'] = df['Lot Frontage'].fillna(0)

# %%
percent_nan = percent_missing(df)

sns.barplot(x=percent_nan.index, y=percent_nan)
ax = plt.gca()
plt.xticks(rotation=90);
plt.xlabel("Columns (features) with missing data")
plt.ylabel("Percentage of missing data")
plt.figure(figsize=(8,4), dpi=200)
